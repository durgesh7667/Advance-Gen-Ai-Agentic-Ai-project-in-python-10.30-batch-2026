# %% [markdown]
# # 13.03.26 complex data type

# %%
complex(10)  #complex data type creating all data type to real and imaginary form except string.
# Out:
# (10+0j)

# %%
complex(0)
# Out:
# 0j

# %%
complex(2.3)
# Out:
# (2.3+0j)

# %%
complex(2.3, 4.5)
# Out:
# (2.3+4.5j)

# %%
complex(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 complex(10,20,30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(24,2.4)
# Out:
# (24+2.4j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex(True,False)  # Here true and false is boolean that's why error not occured.
# Out:
# (1+0j)

# %%
complex('True')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 complex('True')
#
# ValueError: complex() arg is a malformed string

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('10', '20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 complex('10', '20')
#
# TypeError: complex() can't take second arg if first is a string

# %%
a=complex(4,5)
print(a)
# Out:
# (4+5j)

# %%
z=6+7J
print(z.real)
print(z.imag)
# Out:
# 6.0
# 7.0

# %% [markdown]
# # arithmetic operator

# %%
a=5
b=6
print(a+b)
# Out:
# 11

# %%
a*b
# Out:
# 30

# %%
b-a
# Out:
# 1

# %%
b/a #float division
# Out:
# 1.2

# %%
b//a # int division
# Out:
# 1

# %%
b%a  # remainder operator
# Out:
# 1

# %%
2*3
# Out:
# 6

# %%
2**3
# Out:
# 8

# %%
2%3
# Out:
# 2

# %%
10%5
# Out:
# 0

# %% [markdown]
# # assignment operator

# %%
x=2
x
# Out:
# 2

# %%
x+=2
x
# Out:
# 6

# %%
x -=2
x
# Out:
# 4

# %%
x *=2
x
# Out:
# 8

# %%
x  * =2
x
# Out:
#   Cell In[35], line 1
#     x  * =2
#          ^
# SyntaxError: invalid syntax

# %%
x //=2
x
# Out:
# 4

# %% [markdown]
# # unary operator(negation)

# %%
n=7
n
# Out:
# 7

# %%
m=-n
m
# Out:
# -7

# %%
-n
# Out:
# -7

# %% [markdown]
#  # relational operator(comparison operator)

# %%
x=7
y=9

# %%
x<4
# Out:
# False

# %%
x>6
# Out:
# True

# %%
x>y
# Out:
# False

# %%
x<y
# Out:
# True

# %%
x==y
# Out:
# False

# %%
x=y

# %%
x==y
# Out:
# True

# %%
x !=y
# Out:
# False

# %%
print(x)
print(y)
# Out:
# 9
# 9

# %%
x>=y
# Out:
# True

# %% [markdown]
# # logical operator

# %%
x=7
y=9

# %%
x<8 and y>8
# Out:
# True

# %%
x<8 and y<7
# Out:
# False

# %%
x<8 or y<7
# Out:
# True

# %%
x<6 or y<5
# Out:
# False

# %%
x= True
x
# Out:
# True

# %%
x=False
x
# Out:
# False

# %%
not x
# Out:
# True

# %%
8+7*2-1
# Out:
# 21

# %%
print(10)
print(10,20)
print('python')
# Out:
# 10
# 10 20
# python

# %%
a=10
b=20
print(a+b)
# Out:
# 30
