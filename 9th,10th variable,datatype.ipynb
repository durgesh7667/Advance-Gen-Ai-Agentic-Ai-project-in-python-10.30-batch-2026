# %% [markdown]
# ## 09.03.26-python variable

# %%
nit_=7  # in special character only underscore is allowed
# Out:
# 7

# %%
50*5
# Out:
# 250

# %%
nit=23
nit
# Out:
# 23

# %%
durg1=3  # you can right integer after variable but reverse is not allowed.
durg1
# Out:
# 3

# %%
1durg=3
1durg
# Out:
#   Cell In[14], line 1
#     1durg=3
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# # 10.03.26-datatype

# %%
int=5
int
# Out:
# 5

# %%
f1=2.4e1
f1
# Out:
# 24.0

# %%
f1=2.4e3
f1
# Out:
# 2400.0

# %%
False/True  # true=1,false=0, boolean
# Out:
# 0.0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero
