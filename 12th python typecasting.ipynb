# %%
s3='quantamphysics'
s3
# Out:
# 'quantamphysics'

# %%
s3[:]
# Out:
# 'quantamphysics'

# %%
s3[:1]
# Out:
# 'q'

# %%
s3[1:]
# Out:
# 'uantamphysics'

# %%
s3[1:4]
# Out:
# 'uan'

# %%
s3[:-1]
# Out:
# 'quantamphysic'

# %%
s3[::-1]
# Out:
# 'scisyhpmatnauq'

# %%
s3[::1][::-2]
# Out:
# 'siypanu'

# %%
s3[::1]
# Out:
# 'quantamphysics'

# %%
s3[1::]
# Out:
# 'uantamphysics'

# %%
s3[1:8]
# Out:
# 'uantamp'

# %%
s3[1:8:3]
# Out:
# 'utp'

# %% [markdown]
# # 12.03.26 python typecasting

# %%
int(2.3) #float to integer conversion
# Out:
# 2

# %%
int(True)  # in true or false case first letter'T' & 'F' should be capital
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(10)
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
int(2+3j)   #complex int typecasting is not possible.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 int(2+3j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
float(20)
# Out:
# 20.0

# %%
float(True)
# Out:
# 1.0

# %%
float('ten')  # all other datatype can  be possible to convert float except text & complex datatype.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %%
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1+2j)
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool('zero')
# Out:
# True
